# %%
# OPERATIONS

if True:
  print('Hello')
# Out:
# Hello

# %%
applicant_skill = 'SQL'

job_skill = 'SQL'

if applicant_skill == job_skill:
  print('Applicant has the same skill as the job')
# Out:
# Applicant has the same skill as the job

# %%
applicant_skill = 'Excel'

job_skill = 'SQL'

applicant_experience = 5

if applicant_skill == job_skill:
  print('Applicant has the same skill as the job')
elif applicant_experience >= 5:
  print('Applicant has experience')
elif applicant_skill == 'Excel':
  print('Applicant has Excel skill but no SQL')
else:
  print('Applicant has no skill or experience')
# Out:
# Applicant has experience

# %%
 if applicant_skill == job_skill:         # Passes
  pass

# %%
# LISTS

job_skills = ['sql', 'tableau', 'excel']

job_skills.append('python')

print(job_skills)
# Out:
# ['sql', 'tableau', 'excel', 'python']

# %%
job_skills.remove('excel')

print(job_skills)
# Out:
# ['sql', 'tableau', 'python']

# %%
len(job_skills)
# Out:
# 3

# %%
job_skills[1]
# Out:
# 'tableau'

# %%
job_skills.insert(1, 'excel')

print(job_skills)
# Out:
# ['sql', 'excel', 'tableau', 'python']

# %%
job_skills.pop(1)

job_skills
# Out:
# ['sql', 'tableau', 'python']

# %%
#Slicing - Accessing multiple values
# Starting index is included, Ending index is not
#E.g. [0:5] will select 0-4
# Step defaults to 1 [::1]

job_skills[0:2]
# Out:
# ['sql', 'tableau']

# %%
job_skills[:]
# Out:
# ['sql', 'tableau', 'python']

# %%
job_skills[1:]
# Out:
# ['tableau', 'python']

# %%
job_skills[::2]
# Out:
# ['sql', 'python']

# %%
luke_skills = ['python', 'bigquery', 'r']
kelly_skills = ['python', 'sql', 'tableau']

all_skills = luke_skills + kelly_skills

print(all_skills)
# Out:
# ['python', 'bigquery', 'r', 'python', 'sql', 'tableau']

# %%
all_skills[::2]
# Out:
# ['python', 'r', 'sql']

# %%
# Negative numbers can show reverse order
all_skills[-2:]
# Out:
# ['sql', 'tableau']

# %%
#Unpacking
skill1, skill2, skill3 = job_skills

print(skill1)
print(skill2)
print(skill3)
# Out:
# sql
# tableau
# python

# %%
job_skills
# Out:
# ['sql', 'tableau', 'python']

# %%
skill_wanted, *other_skills = job_skills

print(skill_wanted)
print(other_skills)
# Out:
# sql
# ['tableau', 'python']

# %%
# Dictionaries
job_type_skils = {
    'database': 'postgresql',
    'language': 'python',
    'library': 'pandas'
 }

job_type_skils
# Out:
# {'database': 'postgresql', 'language': 'python', 'library': 'pandas'}

# %%
job_type_skils['database']
# Out:
# 'postgresql'

# %%
job_type_skils.keys()
# Out:
# dict_keys(['database', 'language', 'library'])

# %%
job_type_skils.values()
# Out:
# dict_values(['postgresql', 'python', 'pandas'])

# %%
job_type_skils.update({'cloud': 'google'})

# %%
job_type_skils
# Out:
# {'database': 'postgresql',
#  'language': 'python',
#  'library': 'pandas',
#  'cloud': 'google'}

# %%
job_type_skils['version control'] = 'git'  #Easier way to update dictionary

# %%
job_type_skils
# Out:
# {'database': 'postgresql',
#  'language': 'python',
#  'library': 'pandas',
#  'cloud': 'google',
#  'version control': 'git'}

# %%
#SETS
job_skills =  {'sql', 'python', 'sql', 'python', 'tableau'}  # Only has unique values, and automatically orders alphabetically

job_skills
# Out:
# {'python', 'sql', 'tableau'}

# %%
list(set(job_skills))  #Turns a list into a set to remove duplicate values, then turns back into a list to keep its ordering index
# Out:
# ['sql', 'python', 'tableau']

# %%
# TUPLES - very similary to lists, but for fixed values. Tuples are immutable (Cant be changed very much)
my_skills = ('sql', 'python', 'statistics', 'tableau')

my_skills
# Out:
# ('sql', 'python', 'statistics', 'tableau')

# %%
my_skills[0:2]
# Out:
# ('sql', 'python')

# %%
my_skills = ('sql', 'python', 'statistics', 'tableau')
new_skills = ('excel', 'power bi')

# Can use dundees methods with them
my_skills + new_skills

# ^ creates a new variable rather than changing the tuple
# Out:
# ('sql', 'python', 'statistics', 'tableau', 'excel', 'power bi')

# %%
# LOOPS

numbers = [0, 1, 2, 3, 4, 5]

for number in numbers:
  print(number)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
years_experience = {
    'Alice': 2,
    'Bob': 22,
    'Charlie': 2,
    'Diana': 25,
    'Ethan': 9,
    'Fiona': 12,
    'George': 5,
    'Hannah': 9,
    'Ian': 25,
    'Jessica': 9,
    'Kevin': 18,
    'Luna': 26,
    'Mason': 8,
    'Nora': 24,
    'Oliver': 30,
    'Penny': 8,
    'Quinn': 11,
    'Rachel': 24,
    'Sam': 28,
    'Tina': 17,
    'Ulysses': 19,
    'Violet': 9,
    'William': 3,
    'Xavier': 3,
    'Yvonne': 22
}

# %%
for values in years_experience.values():
  print(values)
# Out:
# 2
# 22
# 2
# 25
# 9
# 12
# 5
# 9
# 25
# 9
# 18
# 26
# 8
# 24
# 30
# 8
# 11
# 24
# 28
# 17
# 19
# 9
# 3
# 3
# 22

# %%
for key, values in years_experience.items():
  print(key, values)
# Out:
# Alice 2
# Bob 22
# Charlie 2
# Diana 25
# Ethan 9
# Fiona 12
# George 5
# Hannah 9
# Ian 25
# Jessica 9
# Kevin 18
# Luna 26
# Mason 8
# Nora 24
# Oliver 30
# Penny 8
# Quinn 11
# Rachel 24
# Sam 28
# Tina 17
# Ulysses 19
# Violet 9
# William 3
# Xavier 3
# Yvonne 22

# %%
for key, values in years_experience.items():
  if values >= 10:
    print(key, 'has', values, 'years of experience')
# Out:
# Bob has 22 years of experience
# Diana has 25 years of experience
# Fiona has 12 years of experience
# Ian has 25 years of experience
# Kevin has 18 years of experience
# Luna has 26 years of experience
# Nora has 24 years of experience
# Oliver has 30 years of experience
# Quinn has 11 years of experience
# Rachel has 24 years of experience
# Sam has 28 years of experience
# Tina has 17 years of experience
# Ulysses has 19 years of experience
# Yvonne has 22 years of experience

# %%
count = 1
while count <= 5:
  print(count)
  count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
years = 0
index = 0
years_list = list(years_experience.items())

while years < 10:
  key, years = years_list[index]
  if years >= 10:
    print(key, 'has', years, 'experience')
  index += 1
# Out:
# Bob has 22 experience

# %%
# Excercise


job_roles = [
{'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel']},
{'role': 'Data Scientist', 'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning']},
{'role': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']},
{'role': 'Data Engineer', 'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL']},
{'role': 'Business Intelligence Analyst', 'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']},
{'role': 'Quantitative Analyst', 'skills': ['R', 'Python', 'MATLAB', 'Statistics']},
{'role': 'Operations Analyst', 'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement' ]},
{'role': 'Database Administrator', 'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management' ]},
{'role': 'AI Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']},
{'role': 'Statistician', 'skills': ['R', 'SAS', 'Python', 'Statistical Modeling']}

]

# %%
my_skills = ['Python', 'SQL', 'Excel']

# %%
qualified_roles = []

for job in job_roles:
  qualified = True

  for skill in my_skills:
    if skill not in job['skills']:
      qualified = False
      break
  if qualified:
      qualified_roles.append(job['role'])

print(qualified_roles)
# Out:
# ['Data Analyst', 'Business Intelligence Analyst']

# %%
qualified_roles = []

for job in job_roles:
  if all(skill in job['skills'] for skill in my_skills):
    qualified_roles.append(job['role'])

qualified_roles
# Out:
# ['Data Analyst', 'Business Intelligence Analyst']

# %%
#Functions

base_salary = 100_000
bonus_rate = 0.1
total_salary = base_salary * (1 + bonus_rate)

total_salary
# Out:
# 110000.00000000001

# %%
def calculate_salary(base_salary, bonus_rate):

  total_salary = base_salary * (1 + bonus_rate)

  return total_salary

# %%
calculate_salary(base_salary, bonus_rate)
# Out:
# 110000.00000000001
